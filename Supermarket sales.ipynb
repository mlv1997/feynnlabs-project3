# %%
#importing libraries
import numpy as np
import pandas as pd

# %%
#loading data
df=pd.read_csv('supermarket_sales.csv')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
#Presence of missing values
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#presence of duplicated rows
df.duplicated().sum()
# Out:
# 0

# %%
#converting object to date type
from datetime import datetime
df['Date']=pd.to_datetime(df['Date'])

# %%
#data visualisations
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
plt.rcParams['figure.figsize']=(10,6)
fig1=sns.countplot(data=df,x='Branch',palette='rainbow')
fig1.bar_label(fig1.containers[0])
plt.tight_layout()

# %%
df['City'].value_counts()
# Out:
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: City, dtype: int64

# %%
plt.rcParams['figure.figsize']=(10,6)
fig1=sns.countplot(data=df,x='City',palette='rainbow')
fig1.bar_label(fig1.containers[0])
plt.tight_layout()

# %%
df['Customer type'].value_counts()
# Out:
# Member    501
# Normal    499
# Name: Customer type, dtype: int64

# %%
plt.rcParams['figure.figsize']=(10,6)
fig1=sns.countplot(data=df,x='Customer type',palette='rainbow')
fig1.bar_label(fig1.containers[0])
plt.tight_layout()

# %%
df['Gender'].value_counts()
# Out:
# Female    501
# Male      499
# Name: Gender, dtype: int64

# %%
plt.rcParams['figure.figsize']=(5,5)
labels=['Male','Female']
size=df['Gender'].value_counts()
fig1=plt.pie(size,labels=labels,autopct='%1.1f%%')
plt.tight_layout()

# %%
df['Product line'].value_counts()
# Out:
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: Product line, dtype: int64

# %%
plt.rcParams['figure.figsize']=(10,6)
fig3=sns.countplot(data=df,x='Product line',palette='rainbow')
fig3.bar_label(fig3.containers[0])
plt.xticks(rotation=55)
plt.tight_layout()

# %%
df['Payment'].value_counts()
# Out:
# Ewallet        345
# Cash           344
# Credit card    311
# Name: Payment, dtype: int64

# %%
plt.rcParams['figure.figsize']=(5,5)
labels=['Ewallet','Cash','Credit card']
size=df['Payment'].value_counts()
fig1=plt.pie(size,labels=labels,autopct='%1.1f%%')
plt.tight_layout()

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
#Correlation matrix plot of data
ax= plt.figure(figsize=(12,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#adding column 'Sales' to the dataframe
def df1(df):
    df['Sales']=df['Quantity']*df['Unit price']
    return df

# %%
df1=df1(df)

# %%
df1.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating  \
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df1.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating       Sales
# count             1.000000e+03   1000.000000  1000.00000  1000.00000
# mean              4.761905e+00     15.379369     6.97270   307.58738
# std               6.131498e-14     11.708825     1.71858   234.17651
# ...

# %%
#Correlation matrix plot of data with column 'Sales'
ax= plt.figure(figsize=(12,8))
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
sns.histplot(df1['Unit price'],kde=True,bins=30)
# Out:
# <AxesSubplot:xlabel='Unit price', ylabel='Count'>

# %%
sns.histplot(df1['gross income'],kde=True,bins=30)
# Out:
# <AxesSubplot:xlabel='gross income', ylabel='Count'>

# %%
sns.histplot(df1['Sales'],kde=True,bins=30)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(df1['cogs'],kde=True,bins=30)
# Out:
# <AxesSubplot:xlabel='cogs', ylabel='Count'>

# %%
df1['Quantity'].value_counts()
# Out:
# 10    119
# 1     112
# 4     109
# 7     102
# 5     102
# 6      98
# 9      92
# 2      91
# 3      90
# 8      85
# Name: Quantity, dtype: int64

# %%
plt.rcParams['figure.figsize']=(15,6)
fig3=sns.countplot(data=df,x='Quantity',palette='rainbow')
fig3.bar_label(fig3.containers[0])
plt.tight_layout()

# %%
plt.rcParams['figure.figsize']=(15,6)
fig4=sns.barplot(x='Product line',y='Sales',data=df,palette='Set2')
plt.xticks(rotation=75)
plt.tight_layout()

# %%
plt.rcParams['figure.figsize']=(15,6)
fig4=sns.barplot(x='Branch',y='gross income',data=df,palette='Set2')
plt.xticks(rotation=75)
plt.tight_layout()

# %%
sns.pairplot(df1)
